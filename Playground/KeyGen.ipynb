# %%
#!/usr/bin/env python
# -*-coding:utf-8-*-

# 第 0001 题：做为 Apple Store App 独立开发者，你要搞限时促销，为你的应用生成激活码（或者优惠券），
# 使用 Python 如何生成 200 个激活码（或者优惠券）？

import string
import random

KEY_LEN = 20
KEY_ALL = 200


def base_str():
    return (string.letters+string.digits)


def key_gen():
    keylist = [random.choice(base_str()) for i in range(KEY_LEN)]
    return ("".join(keylist))


def print_key(func):
    def _print_key(num):
        no = 0
        for i in func(num):
            no = no +1
            print i
    return _print_key


@print_key
def key_num(num, result=None):
    
    if result is None:
        result = []
    for i in range(num):
        result.append(key_gen())
    return result


if __name__ == "__main__":
    # print_key(KEY_ALL)
    key_num(KEY_ALL)
# Out:
# gqPj229mu8323rpbT18w
# MCVc5GRENeht1iML8ezj
# OIYf4uz5E7SjMvGbrSWg
# tcjvWYGecAmT3X6DLlGx
# DiQBdOtq6Tpkdpa4JRHU
# kI8PavfI9ax68sQa1G7P
# encPfUuUHrEWvfhtYghL
# zesPGme7ZTcZ2WMUeZoM
# iq5PYp2FN7ew2JV2TDfF
# dVFoSy22xTZo8R1Mv02O
# yLIBVpKdArywRGmkmB5U
# 7BvSgatgun9ofaQmaIQL
# fimUXzbeJK8SWdQHyag6
# GDZedZWF07OuUR2nybz4
# VLrMSMfvpSYqkIiedOvp
# Kudst5jXUZlDYI4VysLk
# TNAJfi83vnpayeS0Rgf7
# ALHRBXPdxdBChQGdB3XR
# 6f6kwDOKZ9fGuf7Uvxmm
# FLJBI5jWO484UwKqlUc3
# lPq9rVK4j41AFtTcfsbk
# wNON9KkSVfjNHXHveMHk
# NsdQnEifKuUOj8EYtKUl
# WKpg9fNtFVHNLg4Aj8bC
# Ie58LpclbrJYwgKWel5I
# cjEo2rxxefqo4xgxChQa
# ov1f61sGhg9VISANb1oa
# wHyCCcSZhMC7pLKTVoSr
# 1LPyuIQqU4FoIaF2s3XS
# j1MBAV5jGA0dh0tSTezF
# 6tNoAx8mF35dxtBHNxue
# QtP8jumETmSrmrOdr0Qy
# 3zsu2d6D53g37ixhqgbv
# CCUHWYku3U6BZ60Dtjq8
# qiPgpig1LfruaVcYyfBN
# Opv3kFOB5OGB5gDAYO8R
# PQG1hisyd8m0xZAtQ58u
# BaWfCsWHctNOldqAN0RQ
# rgROa3FUvTCzwOJhElqg
# C1X0oqwo9bwJpymiOjDW
# LvuTZI65akYJ6OzLv2cL
# 8uw8E3kqnm7LpccEhBSH
# bJEXqTanVrZu8V5UbLJm
# GU2jXr6PMVGlrR9zViAa
# hWCZC4i1UJuVmqMGXgtl
# pLcEP9GARe5b7RraIms0
# MpMm1D1f1dJvZYvuR9gr
# 9nrTsfcb5uIUJdYYy8iX
# ef62A4MKDmKpJShXwai8
# v4TyXVm2VbBP7SMAJ5WP
# 3q5imaoDjDtmzsx2u18q
# eHzILBz4bTUnjI9rxdbi
# YGYIr4UkR3FQIX2pAN3y
# EmiyyDJnWcUZP3KVIW6A
# 0nzRnMDp7vJ35OUnnumj
# XSfdaeYRVov8s5QYyQ6N
# Bgmt4XDm3VYsPLMcmXAM
# ANOk4UCCEVh37ioSj3lV
# AHkOEnzt2fD4rNGnrJPI
# AtXO2nDvtUsaRt6Iuskt

# %% [markdown]
# # 第 0002 题：将 0001 题生成的 200 个激活码（或者优惠券）保存到 MySQL 关系型数据库中。

# %%
#!/usr/bin/env python
# -*-coding:utf-8-*-

# 第 0002 题：将 0001 题生成的 200 个激活码（或者优惠券）保存到 MySQL 关系型数据库中。

import MySQLdb
import string
import random

KEY_LEN = 20
KEY_ALL = 200


def base_str():
    return (string.letters + string.digits)


def key_gen():
    keylist = [random.choice(base_str()) for i in range(KEY_LEN)]
    
    return ("".join(keylist))

def key_num(num, result=None):
    if result is None:
        result = []
    for i in range(num):
        result.append(str(key_gen()))
    return result


class mysql_init(object):

    def __init__(self, conn):
        self.conn = None

    # connect to mysql
    def connect(self):
        self.conn = MySQLdb.connect(
            host="localhost",
            port=3306,
            user="root",
            passwd="k14I12d`",
            db="test",
            charset="utf8"
        )
        print "success connect"

    def cursor(self):
        try:
            return self.conn.cursor()
        except (AttributeError, MySQLdb.OperationalError):
            self.connect()
            return self.conn.cursor()

    def commit(self):
        return self.conn.commit()

    def close(self):
        return self.conn.close()


def process():
    print 'po'
    dbconn.connect()
    conn = dbconn.cursor()
    DropTable(conn)
    CreateTable(conn)
    InsertDatas(conn)
    QueryData(conn)
    dbconn.commit()
    dbconn.close()
    print 'done'

def execute(sql):
    '''执行sql'''
    print 'successfully excuete'
    conn=dbconn.cursor()
    conn.execute(sql)
    

def executemany(sql, tmp):
    '''插入多条数据'''
    conn=dbconn.cursor()
    conn.executemany(sql,tmp)


def query(sql, conn):
    '''查询sql'''
    # conn=dbconn.cursor()
    conn.execute(sql)
    rows = conn.fetchall()
    return rows


def DropTable(conn):
    conn=dbconn.cursor()
    conn.execute("DROP TABLE IF EXISTS `user_key`")


def CreateTable(conn):
    # conn=dbconn.cursor()
    print 'table created'
    sql_create = ''' CREATE TABLE `user_key` (`key` varchar(50) NOT NULL)'''
    conn.execute(sql_create)


def InsertDatas(conn):
    # conn=dbconn.cursor()
    # insert_sql = "insert into user_key values(%s)"
    insert_sql = "INSERT INTO user_key VALUES (%(value)s)"
    key_list = key_num(KEY_ALL)
    print len(key_list)
    # conn.executemany(insert_sql,str(key_listi))
    # conn.executemany("INSERT INTO user_key VALUES (%(value)s)",
    #                   [dict(value=v) for v in key_list])
    conn.executemany(insert_sql, [dict(value=v) for v in key_list])
    print 'key incerted'


def DeleteData():
    del_sql = "delete from user_key where id=2"
    execute(del_sql)


def QueryData(conn):
    sql = "select * from user_key limit 20"
    rows = query(sql, conn)
    printResult(rows)


def printResult(rows):
    i = 0
    if rows is None:
        print "rows None"
    for row in rows:
        i = i +1
        print i,row

if __name__ == "__main__":
    dbconn = mysql_init(None)
    process()
# Out:
# po
# success connect
# table created
# 200
# key incerted
# 1 (u'nIaJUiYvSRX6CWqYGs7N',)
# 2 (u'utFjiRBtI78nymF4luFr',)
# 3 (u'lQyDuEpS4JdLv3yBpcpK',)
# 4 (u'SaGq8eQGQuidZMPbdfEM',)
# 5 (u'eUFrL4xECpv9y3EmA8i9',)
# 6 (u'8OCiYiCay7p8X0YtlpQd',)
# 7 (u'6rGn7TiDznKFEDKg4Krt',)
# 8 (u'WddACPZWymTzLOPBEKE7',)
# 9 (u'oLHVPX8BrRBexzQZxQAA',)
# 10 (u'lh8DDKP0wdccgMGdmcWA',)
# 11 (u'4nfEbcbkjrZBIwF3Bfsf',)
# 12 (u'jP6kqi5xbWAZTqdCeeAX',)
# 13 (u'YTCZeO8DOyk5EDkv61zo',)
# 14 (u'kaPFnJRP7tbUvLdmJ4L6',)
# 15 (u'r4XPELUolDuJW81MZKeT',)
# 16 (u'8PoJNPBfjobEdZDfIwFt',)
# 17 (u'3JPS78kmRtyg4AimQJIE',)
# 18 (u'uiSvVN2z87qbNcUzsNSy',)
# 19 (u'UOGV82BKMlTGDjwcqvil',)
# 20 (u'u797dI1DhECilsjftaXY',)
# done
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:97: Warning: Unknown table 'test.user_key'

# %%
# %load_ext sql
# %sql mysql://root:k14I12d`@localhost/test
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# u'Connected: root@test'

# %%
try:
    import pymysql
    pymysql.install_as_MySQLdb()
    print'success'
except ImportError:
    print 'failed'
    pass
# Out:
# success

# %%
# %%sql
# USE test;
# SELECT * FROM user_key;
# Out:
# 0 rows affected.
# 200 rows affected.
# [('nIaJUiYvSRX6CWqYGs7N',),
#  ('utFjiRBtI78nymF4luFr',),
#  ('lQyDuEpS4JdLv3yBpcpK',),
#  ('SaGq8eQGQuidZMPbdfEM',),
#  ('eUFrL4xECpv9y3EmA8i9',),
#  ('8OCiYiCay7p8X0YtlpQd',),
#  ('6rGn7TiDznKFEDKg4Krt',),
#  ('WddACPZWymTzLOPBEKE7',),
#  ('oLHVPX8BrRBexzQZxQAA',),
#  ('lh8DDKP0wdccgMGdmcWA',),
#  ('4nfEbcbkjrZBIwF3Bfsf',),
#  ('jP6kqi5xbWAZTqdCeeAX',),
#  ('YTCZeO8DOyk5EDkv61zo',),
#  ('kaPFnJRP7tbUvLdmJ4L6',),
#  ('r4XPELUolDuJW81MZKeT',),
#  ('8PoJNPBfjobEdZDfIwFt',),
#  ('3JPS78kmRtyg4AimQJIE',),
#  ('uiSvVN2z87qbNcUzsNSy',),
#  ('UOGV82BKMlTGDjwcqvil',),
#  ('u797dI1DhECilsjftaXY',),
#  ('RK9TMNdzKdXLCinPlBnY',),
#  ('It9x6gU5ejSh2GNBxFR7',),
#  ('Fa7pPmtjhhUjjJPaVTaC',),
#  ('vL4lv8TTXLei4XMm4qyY',),
#  ('5E7mqvcdTb0YESkzzNIp',),
#  ('pY7gA4cYvfh0bpIWb9rA',),
#  ('SpnVKswRl1OZfA7kvuz9',),
#  ('GtUVDUKCUMsYeU35P9cq',),
#  ('2KHvAVoCQLU1gh8GDGjn',),
#  ('d0gpmKG05o3fduo8V1SP',),
#  ('faoRj0DozAusKFQIW57e',),
#  ('trFnAwJeeS8LF0FFNyDn',),
#  ('YZJbbhSP3JPNyoBmqorf',),
#  ('W0Ph2Jr8W7cpERCVARcY',),
#  ('EpqLPtQ8lEunGQSew5BR',),
#  ('3jarK6TSckkIGgsKuaX3',),
#  ('sQ0tPVQpohSgwKF8xpDo',),
#  ('lNyLvSRbQAkc96jKoDbf',),
#  ('vSg9SB9dXxgV6575y7hP',),
#  ('Dxt8XjOT5tGER5WMRt3y',),
#  ('TdN56wFch5b9JBswu5fw',),
#  ('u907r6c0jGVfvy3qlxWa',),
#  ('p8Qf5y9GzGV9fpH7LsKU',),
#  ('69SE2rVKyKkZeNNsVDZN',),
#  ('b8MldSAHtnoEyGzKoVAy',),
#  ('pmgd5nbfjr3lCfKpFPFR',),
#  ('wizDpK3OrduHpflUFMma',),
#  ('a6pkC6zKwsBu7Ye0X2L5',),
#  ('6uF78cCFS0CDepj9CkgV',),
#  ('fahNW5QiVpC0jjdpFvEn',),
#  ('wTNGeajmkdRwpR82rVqL',),
#  ('ZOnftMz1eZ78oVRUxndC',),
#  ('vq7RGxj5ECTadfLthCmz',),
#  ('Rhws13ExNYlC8boctLd8',),
#  ('fojmGcYKjTP7XT7ugpqP',),
#  ('B9wckxwJc08WUaDu0uVS',),
#  ('2GoMwcj4pn4kBbrlspz3',),
#  ('obPBQLhotrPABXGyVH8d',),
#  ('DigojvotGtqbcsFVQimZ',),
#  ('f83ywMDWBJ4SqgJZSLep',),
#  ('1o6h5T7OPhtg9hZdyGM5',),
#  ('gAWY9YA6Acwx3reTYtIl',),
#  ('SnSYMcdkk7vkq0mCHEFf',),
#  ('XuiYtccy8Hpy89wvtbNW',),
#  ('xPDSW8gT4Rewb9kwGUr4',),
#  ('xPArlrd6JGvOznSIja7J',),
#  ('TGdxlZtmy7IjswKX7VjB',),
#  ('6EREfkIoDHfA0gwQGW1b',),
#  ('bgIJp45pulLIVZF0DWwe',),
#  ('Z4m47CCFZbPkjTU7Jofq',),
#  ('b2eBCCZobIekvzZdX8ze',),
#  ('6aQcplhGXjVLQlF9uYte',),
#  ('CBDb7x3TrIXkA6OFRrtd',),
#  ('WXWfiTgbUlIap541z06n',),
#  ('jecaEVxsnoTDs2I1XFcE',),
#  ('tLoZNPd9ymk9lD9B31OF',),
#  ('6kddWJ8y5qbUcux8gVET',),
#  ('aeIgqwqlKXz088mjtoxT',),
#  ('W8scEEZtgd4xIRGBvT0L',),
#  ('njtfOroyLJakWIBqXECB',),
#  ('1uozQGA3k6uNOZjNBMXK',),
#  ('Wa9c7fMqjJVt7sWcHkYK',),
#  ('sL2ulQLpHYBwFjeGC3Sh',),
#  ('pGzaUzjMUlCFF7VOH0WU',),
#  ('3YfKJ0A1KnTcKxxH8rNM',),
#  ('jp9FsyTrlhESQVZovc2D',),
#  ('uCOKEkJJJB6iBtKbHXgL',),
#  ('DErmJuizX8olxGfJf1qz',),
#  ('QjeEjjg8Qn9kwEWDn3f6',),
#  ('rcYwVwyWcOkfhPhoppYi',),
#  ('nwfU2TWnU9aWfbYOHb3L',),
#  ('BNNTdWNQ8i3jPjGOKeFi',),
#  ('aJsExo7QVlOUrltZEPuy',),
#  ('JUqHXAL0lejxOVbp2vDD',),
#  ('mqiAe4JonJeVxRIlkCw6',),
#  ('pajG5SPCyDG2b4Wh9ZPD',),
#  ('cOUSS09icstxajvRY7nO',),
#  ('UsaUsVdrAPUcpZRyq3RO',),
#  ('yP6Mah5AhnyCALcQKfbZ',),
#  ('zuZ5uyP7Kv5OfpZdrwN3',),
#  ('y3UlFDeHRgTq2TaaBDFM',),
#  ('KSrZVmhCP9DNzL9hEzVU',),
#  ('wbpFShOgeMAoFP6EeEi8',),
#  ('qTbO2Q8jeyJpGSs8heaB',),
#  ('tc8WUOWhscDmBTMyRoRe',),
#  ('tH9ASAfxnECfjqQA9tNT',),
#  ('5Jz03nnM9u52I9vZlcHU',),
#  ('YgiXGlZ55wfc1zY9y0iQ',),
#  ('Lnh4Xev5NaSHXAWQEScZ',),
#  ('IbUP39qjBQAkdxCWB7nw',),
#  ('RJB5wUWnGL2OXVcDel0f',),
#  ('VY1hrv7N0l89vWshjtBU',),
#  ('D1qVu5ltx1abgQWuvJGt',),
#  ('Ein3ltSs9eBHzjKNPZEJ',),
#  ('IiT05yPdJ7XH8H5xewam',),
#  ('LqSvj81pURXtoiadqKUD',),
#  ('BMOab9tLW5oonHp0Dz1u',),
#  ('djlQZ4nV4c59mtqgmUmk',),
#  ('qudML2GLhj2qGuNI6c2e',),
#  ('Qv9Mug3cIBtstPy7O9ri',),
#  ('olAQlTWXwvkOlRIj2I6j',),
#  ('9Ong4UulfidDU24N7zAS',),
#  ('HgO7cSQOWBgn5ZA9iE2o',),
#  ('3czlQbKl9633o57566Fi',),
#  ('bizQlq2BGzahwXRZEhV1',),
#  ('kUgSCp2pj8ZVtGnS7oH4',),
#  ('8Aw7zCxuXZLklygT57Zj',),
#  ('ucANX1m6ZUTWvFFYE7tK',),
#  ('h2tilDdgiN3iNrQXXUCR',),
#  ('1FbPsJetpS8fFc0l5wtB',),
#  ('SmZyenwnn7n02NgGQ8WH',),
#  ('ZvTs9UaU6N4QhD7S0QBX',),
#  ('00VN5qXVVO7EMssvjFkI',),
#  ('yGxk46vlcMvFmOxF6fkk',),
#  ('jlJP1Y93CUB1TgnA8aX5',),
#  ('eA3xw1kC3SRA1MZhAe3t',),
#  ('vfm5pbdAkTBN20LfOn3p',),
#  ('qeHF1yOMd9kQnfO3y1tc',),
#  ('OLgSuxBXL8eI9bqIrTDj',),
#  ('hfztcaFwwB8VsR74iUT4',),
#  ('dQZTQVDGHFnFIZuhCdsE',),
#  ('Su0OJgM2JQGVpc62JGhC',),
#  ('TFvjKrydaI8Xz7k9LNad',),
#  ('5jMm58R0UBlIQUFPQLaG',),
#  ('muKKmZTzdrvYt6SDgmJD',),
#  ('nQuyENSpOArq7PV0zX72',),
#  ('BmBtS1i3ZDOe1XEgy9mn',),
#  ('uhmnFUyGO4vGxXDmCNBo',),
#  ('XHCBqwtFEG2z8HCXBWP9',),
#  ('E8HjXyVAigRes2ijQwo0',),
#  ('KIx5qMLM0b6mPti4oiAh',),
#  ('740tA7gCrC130KXk1BgT',),
#  ('xJ9WyLSkDo9T3eBaphQ1',),
#  ('h1BRUtzn8vNrFbBAbN3d',),
#  ('hLTYNXXA7QwMJctAICNO',),
#  ('2VrB7wbBNnSuXbMVVDcp',),
#  ('vAwurvnijGubzP1B21AZ',),
#  ('k1mcE7K9pgAeIbkfTdct',),
#  ('HiI7pqFlNNE1zGomK3a8',),
#  ('nmo9YLEs845HC2CleUEO',),
#  ('sGRRWjLlaWJ0eZKOhvFI',),
#  ('TIz5bDPyqGNaUBbKtHXI',),
#  ('DQ9kG3TXPpHIqPWZs0CF',),
#  ('qrgcRoMMZVNavjTHwjvX',),
#  ('luViCsiFl1CTMy2bL5gQ',),
#  ('epjtIdqZK1jDPkVWnhK3',),
#  ('WiuVon4bClef9KPaCSVS',),
#  ('EewuEpytR5KiEf55pn1J',),
#  ('KlmasYMpIqDqLWDlU99m',),
#  ('EyPP2oTMywSLhlAlc2au',),
#  ('iZUWom3xtAnXwYkDkSNB',),
#  ('JkDOW7TAJV31lnb6mIZk',),
#  ('jjKAkwHNjeS9MgtMNw1q',),
#  ('38t7miq9GJhksfl25zIo',),
#  ('3tboSVcGLPc3aWVo44Ul',),
#  ('cVrsIF9wTkOOjYJOUts3',),
#  ('nt3p5SYmAUu7FiTAEftI',),
#  ('oXg0hnprjNrwY7n7uEfo',),
#  ('rW6RaC1hkNW5LdxWsDmL',),
#  ('UWNE64sKlVVolMeRpTL1',),
#  ('FUSkE8hImhAVSqHec73a',),
#  ('9Pp46u40b8NXqvHrbu53',),
#  ('zbjZWZrgAMTbdsjQGJg3',),
#  ('hKzJYebKbP6Jsj7XdIzG',),
#  ('wKpzVIgLeoED5qqkYe9v',),
#  ('NIEC9gageyGquJpNT3Lv',),
#  ('oiWIrEIvq8qvamgfVtWT',),
#  ('VlYVDiXqqyZGKBFsZw2Y',),
#  ('2CweNnCzCyDEsRaAg8Rb',),
#  ('4ev3Hr2R7ekSt7RvIHb2',),
#  ('fVpsP7NWhpheUwGdvJ0L',),
#  ('5kO67A8aSHGCQPJjvN8f',),
#  ('OZs28HX8g0fnmcWTE6ne',),
#  ('pWe5vBkvVc8wNJPrsoPe',),
#  ('rVbgzqdSWGCifaBVeAG0',),
#  ('hFpX9XonHeH6EKwC5tRI',),
#  ('cM7L3KwtkdJqLmKH4WCD',),
#  ('9c9PXUiyRUTdDppgePoL',),
#  ('Z3Y67KCJH3MgRCR8iCeF',),
#  ('902dDxTGsXzRdVc7Gqwm',)]
