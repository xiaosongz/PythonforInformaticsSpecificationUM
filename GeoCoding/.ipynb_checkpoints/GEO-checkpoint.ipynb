# %% [markdown]
# Geocode - Python Access to database final peer reviewed project

# %%
import urllib
import sqlite3
import json
import time
import ssl

# Google API (requires API key)
# serviceurl = "http://maps.googleapis.com/maps/api/geocode/json?"
# If you are in China this URL might work (with key):
# serviceurl = "http://maps.google.cn/maps/api/geocode/json?"

serviceurl = "http://python-data.dr-chuck.net/geojson?"


# Deal with SSL certificate anomalies Python > 2.7
# scontext = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
scontext = None

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 : 
        print 'Retrieved 200 locations, restart to retrieve more'
        break
    address = line.strip()
    print ''
    cur.execute("SELECT geodata FROM Locations WHERE address= ?", (buffer(address), ))

    try:
        data = cur.fetchone()[0]
        print "Found in database ",address
        continue
    except:
        pass

    print 'Resolving', address
    url = serviceurl + urllib.urlencode({"sensor":"false", "address": address})
    print 'Retrieving', url
    uh = urllib.urlopen(url, context=scontext)
    data = uh.read()
    print 'Retrieved',len(data),'characters',data[:20].replace('\n',' ')
    count = count + 1
    try: 
        js = json.loads(str(data))
        # print js  # We print in case unicode causes an error
    except: 
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') : 
        print '==== Failure To Retrieve ===='
        print data
        continue

    cur.execute('''INSERT INTO Locations (address, geodata) 
            VALUES ( ?, ? )''', ( buffer(address),buffer(data) ) )
    conn.commit() 
    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(5)

print "Run geodump.py to read the data from the database so you can visualize it on a map."
# Out:
# Resolving AGH University of Science and Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=AGH+University+of+Science+and+Technology
# Retrieved 2761 characters {    "results" : [
#
# Resolving Academy of Fine Arts Warsaw Poland
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Academy+of+Fine+Arts+Warsaw+Poland
# Retrieved 1949 characters {    "results" : [
#
# Resolving American University in Cairo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=American+University+in+Cairo
# Retrieved 10608 characters {    "results" : [
#
# Resolving Arizona State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Arizona+State+University
# Retrieved 2098 characters {    "results" : [
#
# Resolving Athens Information Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Athens+Information+Technology
# Retrieved 2464 characters {    "results" : [
#
# Resolving BITS Pilani
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=BITS+Pilani
# Retrieved 2099 characters {    "results" : [
#
# Resolving Babcock University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Babcock+University
# Retrieved 14524 characters {    "results" : [
#
# Resolving Banaras Hindu University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Banaras+Hindu+University
# Retrieved 2067 characters {    "results" : [
#
# Resolving Bangalore University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Bangalore+University
# Retrieved 2149 characters {    "results" : [
#
# Resolving Baylor University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Baylor+University
# Retrieved 2117 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Beijing normal university
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Beijing+normal+university
# Retrieved 2143 characters {    "results" : [
#
# Resolving Belarusian State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Belarusian+State+University
# Retrieved 2057 characters {    "results" : [
#
# Resolving Belgrade University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Belgrade+University
# Retrieved 2270 characters {    "results" : [
#
# Resolving Beloit College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Beloit+College
# Retrieved 2089 characters {    "results" : [
#
# Resolving Belorussian State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Belorussian+State+University
# Retrieved 2057 characters {    "results" : [
#
# Resolving Ben Gurion University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Ben+Gurion+University
# Retrieved 19766 characters {    "results" : [
#
# Resolving Bharthidasan University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Bharthidasan+University
# Retrieved 2220 characters {    "results" : [
#
# Resolving Boston University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Boston+University
# Retrieved 12348 characters {    "results" : [
#
# Resolving California Polytechnic State University of San Luis Obispo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=California+Polytechnic+State+University+of+San+Luis+Obispo
# Retrieved 1806 characters {    "results" : [
#
# Resolving California State University San Bernardino
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=California+State+University+San+Bernardino
# Retrieved 1965 characters {    "results" : [
# Pausing for a bit...
#
# Resolving City of Westminster College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=City+of+Westminster+College
# Retrieved 33509 characters {    "results" : [
#
# Resolving Columbia University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Columbia+University
# Retrieved 42616 characters {    "results" : [
#
# Resolving Cranfield University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Cranfield+University
# Retrieved 2207 characters {    "results" : [
#
# Resolving Czech Technical University in Prague
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Czech+Technical+University+in+Prague
# Retrieved 1817 characters {    "results" : [
#
# Resolving Dartmouth
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Dartmouth
# Retrieved 3695 characters {    "results" : [
#
# Resolving De Anza College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=De+Anza+College
# Retrieved 2090 characters {    "results" : [
#
# Resolving Distant University of Hagen
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Distant+University+of+Hagen
# Retrieved 1790 characters {    "results" : [
#
# Resolving Dnipropetrovsk National University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Dnipropetrovsk+National+University
# Retrieved 1864 characters {    "results" : [
#
# Resolving Dokuz Eylul University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Dokuz+Eylul+University
# Retrieved 2164 characters {    "results" : [
#
# Resolving Drexel
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Drexel
# Retrieved 9502 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Drexel University and University of Texas at Austin
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Drexel+University+and+University+of+Texas+at+Austin
# Retrieved 11019 characters {    "results" : [
#
# Resolving Duke University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Duke+University
# Retrieved 2099 characters {    "results" : [
#
# Resolving EM Lyon
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=EM+Lyon
# Retrieved 1822 characters {    "results" : [
#
# Resolving Ecole centrale de PARIS
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Ecole+centrale+de+PARIS
# Retrieved 2066 characters {    "results" : [
#
# Resolving Elon University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Elon+University
# Retrieved 1941 characters {    "results" : [
#
# Resolving Erhvervsakademi Sydvest
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Erhvervsakademi+Sydvest
# Retrieved 2130 characters {    "results" : [
#
# Resolving Escuela Superior Politecnica del Litoral
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Escuela+Superior+Politecnica+del+Litoral
# Retrieved 1868 characters {    "results" : [
#
# Resolving Fachhochschule Dusseldorf
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Fachhochschule+Dusseldorf
# Retrieved 2555 characters {    "results" : [
#
# Resolving Fachhochschule FH Salzburg
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Fachhochschule+FH+Salzburg
# Retrieved 1737 characters {    "results" : [
#
# Resolving Faculdade de Tecnologia do Estado de Sao Paulo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo
# Retrieved 2715 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Faculty of Technical Sciences Novi Sad Serbia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Faculty+of+Technical+Sciences+Novi+Sad+Serbia
# Retrieved 1951 characters {    "results" : [
#
# Resolving Farmingdale State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Farmingdale+State+University
# Retrieved 2202 characters {    "results" : [
#
# Resolving Federal University of Minas Gerais
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Federal+University+of+Minas+Gerais
# Retrieved 2813 characters {    "results" : [
#
# Resolving Florida Atlantic University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Florida+Atlantic+University
# Retrieved 2335 characters {    "results" : [
#
# Resolving Franklin Pierce College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Franklin+Pierce+College
# Retrieved 2344 characters {    "results" : [
#
# Resolving Gauhati University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Gauhati+University
# Retrieved 2170 characters {    "results" : [
#
# Resolving George Mason University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=George+Mason+University
# Retrieved 1977 characters {    "results" : [
#
# Resolving Georgetown University Law Center
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Georgetown+University+Law+Center
# Retrieved 2019 characters {    "results" : [
#
# Resolving Georgia State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Georgia+State+University
# Retrieved 5383 characters {    "results" : [
#
# Resolving Grandville
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Grandville
# Retrieved 1752 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Groep T University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Groep+T+University
# Retrieved 17717 characters {    "results" : [
#
# Resolving Hanoi University of Science and Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Hanoi+University+of+Science+and+Technology
# Retrieved 2442 characters {    "results" : [
#
# Resolving Hebrew University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Hebrew+University
# Retrieved 1641 characters {    "results" : [
#
# Resolving IIIT Hyderabad
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=IIIT+Hyderabad
# Retrieved 1927 characters {    "results" : [
#
# Resolving IIT KANPUR
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=IIT+KANPUR
# Retrieved 12063 characters {    "results" : [
#
# Resolving IT College of Estonia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=IT+College+of+Estonia
# Retrieved 2006 characters {    "results" : [
#
# Resolving IU
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=IU
# Retrieved 1376 characters {    "results" : [
#
# Resolving IUAV Venezia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=IUAV+Venezia
# Retrieved 2074 characters {    "results" : [
#
# Resolving Illinois Institute of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Illinois+Institute+of+Technology
# Retrieved 2264 characters {    "results" : [
#
# Resolving Illinois State University Joliet Junior College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Illinois+State+University+Joliet+Junior+College
# Retrieved 1432 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Indian Institute of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Indian+Institute+of+Technology
# Retrieved 2016 characters {    "results" : [
#
# Resolving Indian Institute of Technology Kharagpur India
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Indian+Institute+of+Technology+Kharagpur+India
# Retrieved 2133 characters {    "results" : [
#
# Resolving Indian School of Mines Dhanbad
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Indian+School+of+Mines+Dhanbad
# Retrieved 1765 characters {    "results" : [
#
# Resolving Indiana University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Indiana+University
# Retrieved 2311 characters {    "results" : [
#
# Resolving Indiana University at Bloomington
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Indiana+University+at+Bloomington
# Retrieved 2715 characters {    "results" : [
#
# Resolving Institut Superieur de technologies
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Institut+Superieur+de+technologies
# Retrieved 1782 characters {    "results" : [
#
# Resolving Institute of Business and Modern Technologies
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Institute+of+Business+and+Modern+Technologies
# Retrieved 2429 characters {    "results" : [
#
# Resolving Instituto Tecnologico de Santo Domingo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Instituto+Tecnologico+de+Santo+Domingo
# Retrieved 1783 characters {    "results" : [
#
# Resolving International Institute of Information Technology Hyderabad
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=International+Institute+of+Information+Technology+Hyderabad
# Retrieved 1575 characters {    "results" : [
#
# Resolving Irkutsk State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Irkutsk+State+University
# Retrieved 1787 characters {    "results" : [
# Pausing for a bit...
#
# Resolving JADAVPUR UNIVERSITY
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=JADAVPUR+UNIVERSITY
# Retrieved 9792 characters {    "results" : [
#
# Resolving Jawaharlal Nehru Technological University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Jawaharlal+Nehru+Technological+University
# Retrieved 4471 characters {    "results" : [
#
# Resolving Jawaharlal Nehru University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Jawaharlal+Nehru+University
# Retrieved 2013 characters {    "results" : [
#
# Resolving Jordan University of Science and Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Jordan+University+of+Science+and+Technology
# Retrieved 1977 characters {    "results" : [
#
# Resolving K-State
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=K-State
# Retrieved 1752 characters {    "results" : [
#
# Resolving KUL
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=KUL
# Retrieved 5168 characters {    "results" : [
#
# Resolving Kalamazoo College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kalamazoo+College
# Retrieved 7357 characters {    "results" : [
#
# Resolving Kaunas Technology University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kaunas+Technology+University
# Retrieved 1771 characters {    "results" : [
#
# Resolving Kaunas university of technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kaunas+university+of+technology
# Retrieved 1771 characters {    "results" : [
#
# Resolving Kazan Federal University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kazan+Federal+University
# Retrieved 1775 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Kent State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kent+State+University
# Retrieved 2191 characters {    "results" : [
#
# Resolving Kharkiv State Academy of Municipal Economy Ukraine
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine
# Retrieved 1798 characters {    "results" : [
#
# Resolving King Mongkuts University of Technology Thonburi
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=King+Mongkuts+University+of+Technology+Thonburi
# Retrieved 1795 characters {    "results" : [
#
# Resolving Kokshetau Institute of Economics and Management
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kokshetau+Institute+of+Economics+and+Management
# Retrieved 1956 characters {    "results" : [
#
# Resolving Kyiv Polytechnic Institute
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kyiv+Polytechnic+Institute
# Retrieved 2197 characters {    "results" : [
#
# Resolving Kyiv Polytechnical Institute
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kyiv+Polytechnical+Institute
# Retrieved 2197 characters {    "results" : [
#
# Resolving Kyiv Unisersity of Oriental Language
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Kyiv+Unisersity+of+Oriental+Language
# Retrieved 1729 characters {    "results" : [
#
# Resolving Laurentian University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Laurentian+University
# Retrieved 2530 characters {    "results" : [
#
# Resolving Lisandro Alvarado
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Lisandro+Alvarado
# Retrieved 1928 characters {    "results" : [
#
# Resolving Lodz University of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Lodz+University+of+Technology
# Retrieved 2465 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Lviv University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Lviv+University
# Retrieved 1778 characters {    "results" : [
#
# Resolving MSU
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=MSU
# Retrieved 1661 characters {    "results" : [
#
# Resolving Madras university
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Madras+university
# Retrieved 17380 characters {    "results" : [
#
# Resolving Magnitogorsk State Technical University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Magnitogorsk+State+Technical+University
# Retrieved 1831 characters {    "results" : [
#
# Resolving Malayer Azad University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Malayer+Azad+University
# Retrieved 1575 characters {    "results" : [
#
# Resolving Marietta College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Marietta+College
# Retrieved 2123 characters {    "results" : [
#
# Resolving Masdar Institute
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Masdar+Institute
# Retrieved 1884 characters {    "results" : [
#
# Resolving Matematicki fakultet Beograd
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Matematicki+fakultet+Beograd
# Retrieved 1758 characters {    "results" : [
#
# Resolving Michigan State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Michigan+State+University
# Retrieved 10287 characters {    "results" : [
#
# Resolving Middle East Technical University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Middle+East+Technical+University
# Retrieved 1408 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Missouri University of Science and Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Missouri+University+of+Science+and+Technology
# Retrieved 2223 characters {    "results" : [
#
# Resolving Monash
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Monash
# Retrieved 6634 characters {    "results" : [
#
# Resolving Monash University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Monash+University
# Retrieved 2054 characters {    "results" : [
#
# Resolving Monash University Churchill Australia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Monash+University+Churchill+Australia
# Retrieved 2056 characters {    "results" : [
#
# Resolving Monterrey Institute of Technology and Higher Education
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Monterrey+Institute+of+Technology+and+Higher+Education
# Retrieved 1767 characters {    "results" : [
#
# Resolving Moscow Engineering-Physics Institute
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Moscow+Engineering-Physics+Institute
# Retrieved 3480 characters {    "results" : [
#
# Resolving Moscow Institute of Physics & Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Moscow+Institute+of+Physics+%26+Technology
# Retrieved 3480 characters {    "results" : [
#
# Resolving Moscow State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Moscow+State+University
# Retrieved 2792 characters {    "results" : [
#
# Resolving NIT ROURKELA
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=NIT+ROURKELA
# Retrieved 2283 characters {    "results" : [
#
# Resolving NYU
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=NYU
# Retrieved 9731 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Nagpur University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Nagpur+University
# Retrieved 2111 characters {    "results" : [
#
# Resolving Nanyang Technological University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Nanyang+Technological+University
# Retrieved 2215 characters {    "results" : [
#
# Resolving National Institute of Technology Jalandhar
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=National+Institute+of+Technology+Jalandhar
# Retrieved 1785 characters {    "results" : [
#
# Resolving National Taiwan University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=National+Taiwan+University
# Retrieved 2033 characters {    "results" : [
#
# Resolving National University of Engineering
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=National+University+of+Engineering
# Retrieved 2162 characters {    "results" : [
#
# Resolving North Central College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=North+Central+College
# Retrieved 12154 characters {    "results" : [
#
# Resolving Northeastern University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Northeastern+University
# Retrieved 2108 characters {    "results" : [
#
# Resolving Northwestern University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Northwestern+University
# Retrieved 10546 characters {    "results" : [
#
# Resolving Obninsk Technical University of Nuclear Power Engineering Russia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Obninsk+Technical+University+of+Nuclear+Power+Engineering+Russia
# Retrieved 1770 characters {    "results" : [
#
# Resolving Old Dominion University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Old+Dominion+University
# Retrieved 2413 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Oregon Institute of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Oregon+Institute+of+Technology
# Retrieved 2005 characters {    "results" : [
#
# Resolving PUCMM
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=PUCMM
# Retrieved 8109 characters {    "results" : [
#
# Resolving Payame Noor University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Payame+Noor+University
# Retrieved 48300 characters {    "results" : [
#
# Resolving Penn State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Penn+State+University
# Retrieved 1748 characters {    "results" : [
#
# Resolving Politecnico di Milano
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Politecnico+di+Milano
# Retrieved 2344 characters {    "results" : [
#
# Resolving Politehnica University Bucharest
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Politehnica+University+Bucharest
# Retrieved 1752 characters {    "results" : [
#
# Resolving Polytechnic University of Timisoara
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Polytechnic+University+of+Timisoara
# Retrieved 1754 characters {    "results" : [
#
# Resolving Pondicherry University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Pondicherry+University
# Retrieved 2125 characters {    "results" : [
#
# Resolving Pontificia universidad catolica de chile
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Pontificia+universidad+catolica+de+chile
# Retrieved 2196 characters {    "results" : [
#
# Resolving Portland State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Portland+State+University
# Retrieved 2340 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Purdue University Indianapolis
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Purdue+University+Indianapolis
# Retrieved 2341 characters {    "results" : [
#
# Resolving R V College of Engineering
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=R+V+College+of+Engineering
# Retrieved 17334 characters {    "results" : [
#
# Resolving RPI
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=RPI
# Retrieved 2679 characters {    "results" : [
#
# Resolving Ramapo College of New Jersey
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Ramapo+College+of+New+Jersey
# Retrieved 2254 characters {    "results" : [
#
# Resolving Rochester Institute of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Rochester+Institute+of+Technology
# Retrieved 2326 characters {    "results" : [
#
# Resolving SASTRA University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=SASTRA+University
# Retrieved 2156 characters {    "results" : [
#
# Resolving Saint Petersburg State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Saint+Petersburg+State+University
# Retrieved 1797 characters {    "results" : [
#
# Resolving Saint Petersburg State University of Aerospace Instrumentation
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation
# Retrieved 1797 characters {    "results" : [
#
# Resolving Saint-Petersburg Polytechnic Univesity
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Saint-Petersburg+Polytechnic+Univesity
# Retrieved 1797 characters {    "results" : [
#
# Resolving San Francisco State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=San+Francisco+State+University
# Retrieved 2279 characters {    "results" : [
# Pausing for a bit...
#
# Resolving San Jose State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=San+Jose+State+University
# Retrieved 2268 characters {    "results" : [
#
# Resolving Shanghai Jiao Tong University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Shanghai+Jiao+Tong+University
# Retrieved 2361 characters {    "results" : [
#
# Resolving Sharif University of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Sharif+University+of+Technology
# Retrieved 2408 characters {    "results" : [
#
# Resolving Simon Bolivar University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Simon+Bolivar+University
# Retrieved 11285 characters {    "results" : [
#
# Resolving Simon Fraser University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Simon+Fraser+University
# Retrieved 2365 characters {    "results" : [
#
# Resolving Smolensk State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Smolensk+State+University
# Retrieved 1781 characters {    "results" : [
#
# Resolving Sonoma State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Sonoma+State+University
# Retrieved 1797 characters {    "results" : [
#
# Resolving South Federal University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=South+Federal+University
# Retrieved 2101 characters {    "results" : [
#
# Resolving Spiru Haret University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Spiru+Haret+University
# Retrieved 4619 characters {    "results" : [
#
# Resolving Stanford
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Stanford
# Retrieved 1751 characters {    "results" : [
# Pausing for a bit...
#
# Resolving State University of Campinas
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=State+University+of+Campinas
# Retrieved 1790 characters {    "results" : [
#
# Resolving State University of New York College at Oswego
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=State+University+of+New+York+College+at+Oswego
# Retrieved 3720 characters {    "results" : [
#
# Resolving Stellenbosch University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Stellenbosch+University
# Retrieved 2534 characters {    "results" : [
#
# Resolving Stonehill College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Stonehill+College
# Retrieved 1965 characters {    "results" : [
#
# Resolving Tallinn University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tallinn+University
# Retrieved 2178 characters {    "results" : [
#
# Resolving Tallinn University of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tallinn+University+of+Technology
# Retrieved 2178 characters {    "results" : [
#
# Resolving Tampere University of Technology
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tampere+University+of+Technology
# Retrieved 1616 characters {    "results" : [
#
# Resolving Tanta University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tanta+University
# Retrieved 1773 characters {    "results" : [
#
# Resolving Tarrant County College
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tarrant+County+College
# Retrieved 1969 characters {    "results" : [
#
# Resolving Technical University of Cluj-Napoca
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Technical+University+of+Cluj-Napoca
# Retrieved 1763 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Technion
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Technion
# Retrieved 1816 characters {    "results" : [
#
# Resolving Tel Aviv University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tel+Aviv+University
# Retrieved 1619 characters {    "results" : [
#
# Resolving The Jerusalem collage of engineering
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=The+Jerusalem+collage+of+engineering
# Retrieved 1655 characters {    "results" : [
#
# Resolving The University of Latvia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=The+University+of+Latvia
# Retrieved 2418 characters {    "results" : [
#
# Resolving The University of Manchester
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=The+University+of+Manchester
# Retrieved 11084 characters {    "results" : [
#
# Resolving The University of South Africa
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=The+University+of+South+Africa
# Retrieved 38124 characters {    "results" : [
#
# Resolving Transilvania University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Transilvania+University
# Retrieved 8369 characters {    "results" : [
#
# Resolving Tufts University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Tufts+University
# Retrieved 2662 characters {    "results" : [
#
# Resolving UC Berkeley
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UC+Berkeley
# Retrieved 1965 characters {    "results" : [
#
# Resolving UCLA
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UCLA
# Retrieved 2287 characters {    "results" : [
# Pausing for a bit...
#
# Resolving UCSD
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UCSD
# Retrieved 2526 characters {    "results" : [
#
# Resolving UIUC
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UIUC
# Retrieved 2050 characters {    "results" : [
#
# Resolving UMD
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UMD
# Retrieved 2455 characters {    "results" : [
#
# Resolving UNISA
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UNISA
# Retrieved 2102 characters {    "results" : [
#
# Resolving UNIVERSIDAD DE Buenos Aires
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UNIVERSIDAD+DE+Buenos+Aires
# Retrieved 2002 characters {    "results" : [
#
# Resolving UOC
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UOC
# Retrieved 1606 characters {    "results" : [
#
# Resolving USC
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=USC
# Retrieved 1596 characters {    "results" : [
#
# Resolving UW Madison
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=UW+Madison
# Retrieved 2442 characters {    "results" : [
#
# Resolving Universidad Central de Venezuela
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Central+de+Venezuela
# Retrieved 12236 characters {    "results" : [
#
# Resolving Universidad Complutense de Madrid
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Complutense+de+Madrid
# Retrieved 1929 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Universidad Cooperativa de Colombia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Cooperativa+de+Colombia
# Retrieved 2023 characters {    "results" : [
#
# Resolving Universidad Nacional Autonoma de Mexico
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Nacional+Autonoma+de+Mexico
# Retrieved 2069 characters {    "results" : [
#
# Resolving Universidad Nacional Costa Rica
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Nacional+Costa+Rica
# Retrieved 1868 characters {    "results" : [
#
# Resolving Universidad Nacional de Colombia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Nacional+de+Colombia
# Retrieved 11676 characters {    "results" : [
#
# Resolving Universidad Tecnologica Boliviana
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+Tecnologica+Boliviana
# Retrieved 2394 characters {    "results" : [
#
# Resolving Universidad de Buenos Aires
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+Buenos+Aires
# Retrieved 2002 characters {    "results" : [
#
# Resolving Universidad de Castilla La Mancha
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+Castilla+La+Mancha
# Retrieved 2333 characters {    "results" : [
#
# Resolving Universidad de Los Andes Colombia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+Los+Andes+Colombia
# Retrieved 6734 characters {    "results" : [
#
# Resolving Universidad de Oriente
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+Oriente
# Retrieved 35826 characters {    "results" : [
#
# Resolving Universidad de San Carlos de Guatemala
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+San+Carlos+de+Guatemala
# Retrieved 7475 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Universidad de Valladolid
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+Valladolid
# Retrieved 2291 characters {    "results" : [
#
# Resolving Universidad de la Sabana
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+de+la+Sabana
# Retrieved 1943 characters {    "results" : [
#
# Resolving Universidad del Valle de Guatemala
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidad+del+Valle+de+Guatemala
# Retrieved 1755 characters {    "results" : [
#
# Resolving Universidade Federal da Paraiba
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+Federal+da+Paraiba
# Retrieved 2340 characters {    "results" : [
#
# Resolving Universidade Federal de Santa Catarina
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+Federal+de+Santa+Catarina
# Retrieved 1799 characters {    "results" : [
#
# Resolving Universidade Federal do Rio Grande do Sul
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+Federal+do+Rio+Grande+do+Sul
# Retrieved 2074 characters {    "results" : [
#
# Resolving Universidade Federal do Rio de Janeiro
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+Federal+do+Rio+de+Janeiro
# Retrieved 2086 characters {    "results" : [
#
# Resolving Universidade Tecnica de Lisboa
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+Tecnica+de+Lisboa
# Retrieved 1813 characters {    "results" : [
#
# Resolving Universidade de Sao Paulo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+de+Sao+Paulo
# Retrieved 2155 characters {    "results" : [
#
# Resolving Universidade do Minho
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universidade+do+Minho
# Retrieved 1787 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Universitas Gadjah Mada
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universitas+Gadjah+Mada
# Retrieved 2098 characters {    "results" : [
# Retrieved 200 locations, restart to retrieve more
# Run geodump.py to read the data from the database so you can visualize it on a map.
