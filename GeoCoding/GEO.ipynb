# %% [markdown]
# Geocode - Python Access to database final peer reviewed project

# %%
import urllib
import sqlite3
import json
import time
import ssl

# Google API (requires API key)
# serviceurl = "http://maps.googleapis.com/maps/api/geocode/json?"
# If you are in China this URL might work (with key):
# serviceurl = "http://maps.google.cn/maps/api/geocode/json?"

serviceurl = "http://python-data.dr-chuck.net/geojson?"


# Deal with SSL certificate anomalies Python > 2.7
# scontext = ssl.SSLContext(ssl.PROTOCOL_TLSv1)
scontext = None

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

fh = open("where.data")
count = 0
for line in fh:
    if count > 300 : 
        print 'Retrieved 200 locations, restart to retrieve more'
        break
    address = line.strip()
    print ''
    cur.execute("SELECT geodata FROM Locations WHERE address= ?", (buffer(address), ))

    try:
        data = cur.fetchone()[0]
        print "Found in database ",address
        continue
    except:
        pass

    print 'Resolving', address
    url = serviceurl + urllib.urlencode({"sensor":"false", "address": address})
    print 'Retrieving', url
    uh = urllib.urlopen(url, context=scontext)
    data = uh.read()
    print 'Retrieved',len(data),'characters',data[:20].replace('\n',' ')
    count = count + 1
    try: 
        js = json.loads(str(data))
        # print js  # We print in case unicode causes an error
    except: 
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') : 
        print '==== Failure To Retrieve ===='
        print data
        continue

    cur.execute('''INSERT INTO Locations (address, geodata) 
            VALUES ( ?, ? )''', ( buffer(address),buffer(data) ) )
    conn.commit() 
    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(1)

print "Run geodump.py to read the data from the database so you can visualize it on a map."
# Out:
# Found in database  AGH University of Science and Technology
#
# Found in database  Academy of Fine Arts Warsaw Poland
#
# Found in database  American University in Cairo
#
# Found in database  Arizona State University
#
# Found in database  Athens Information Technology
#
# Found in database  BITS Pilani
#
# Found in database  Babcock University
#
# Found in database  Banaras Hindu University
#
# Found in database  Bangalore University
#
# Found in database  Baylor University
#
# Found in database  Beijing normal university
#
# Found in database  Belarusian State University
#
# Found in database  Belgrade University
#
# Found in database  Beloit College
#
# Found in database  Belorussian State University
#
# Found in database  Ben Gurion University
#
# Found in database  Bharthidasan University
#
# Found in database  Boston University
#
# Found in database  California Polytechnic State University of San Luis Obispo
#
# Found in database  California State University San Bernardino
#
# Found in database  City of Westminster College
#
# Found in database  Columbia University
#
# Found in database  Cranfield University
#
# Found in database  Czech Technical University in Prague
#
# Found in database  Dartmouth
#
# Found in database  De Anza College
#
# Found in database  Distant University of Hagen
#
# Found in database  Dnipropetrovsk National University
#
# Found in database  Dokuz Eylul University
#
# Found in database  Drexel
#
# Found in database  Drexel University and University of Texas at Austin
#
# Found in database  Duke University
#
# Found in database  EM Lyon
#
# Found in database  Ecole centrale de PARIS
#
# Found in database  Elon University
#
# Found in database  Erhvervsakademi Sydvest
#
# Found in database  Escuela Superior Politecnica del Litoral
#
# Found in database  Fachhochschule Dusseldorf
#
# Found in database  Fachhochschule FH Salzburg
#
# Found in database  Faculdade de Tecnologia do Estado de Sao Paulo
#
# Found in database  Faculty of Technical Sciences Novi Sad Serbia
#
# Found in database  Farmingdale State University
#
# Found in database  Federal University of Minas Gerais
#
# Found in database  Florida Atlantic University
#
# Found in database  Franklin Pierce College
#
# Found in database  Gauhati University
#
# Found in database  George Mason University
#
# Found in database  Georgetown University Law Center
#
# Found in database  Georgia State University
#
# Found in database  Grandville
#
# Found in database  Groep T University
#
# Found in database  Hanoi University of Science and Technology
#
# Found in database  Hebrew University
#
# Found in database  IIIT Hyderabad
#
# Found in database  IIT KANPUR
#
# Found in database  IT College of Estonia
#
# Found in database  IU
#
# Found in database  IUAV Venezia
#
# Found in database  Illinois Institute of Technology
#
# Found in database  Illinois State University Joliet Junior College
#
# Found in database  Indian Institute of Technology
#
# Found in database  Indian Institute of Technology Kharagpur India
#
# Found in database  Indian School of Mines Dhanbad
#
# Found in database  Indiana University
#
# Found in database  Indiana University at Bloomington
#
# Found in database  Institut Superieur de technologies
#
# Found in database  Institute of Business and Modern Technologies
#
# Found in database  Instituto Tecnologico de Santo Domingo
#
# Found in database  International Institute of Information Technology Hyderabad
#
# Found in database  Irkutsk State University
#
# Found in database  JADAVPUR UNIVERSITY
#
# Found in database  Jawaharlal Nehru Technological University
#
# Found in database  Jawaharlal Nehru University
#
# Found in database  Jordan University of Science and Technology
#
# Found in database  K-State
#
# Found in database  KUL
#
# Found in database  Kalamazoo College
#
# Found in database  Kaunas Technology University
#
# Found in database  Kaunas university of technology
#
# Found in database  Kazan Federal University
#
# Found in database  Kent State University
#
# Found in database  Kharkiv State Academy of Municipal Economy Ukraine
#
# Found in database  King Mongkuts University of Technology Thonburi
#
# Found in database  Kokshetau Institute of Economics and Management
#
# Found in database  Kyiv Polytechnic Institute
#
# Found in database  Kyiv Polytechnical Institute
#
# Found in database  Kyiv Unisersity of Oriental Language
#
# Found in database  Laurentian University
#
# Found in database  Lisandro Alvarado
#
# Found in database  Lodz University of Technology
#
# Found in database  Lviv University
#
# Found in database  MSU
#
# Found in database  Madras university
#
# Found in database  Magnitogorsk State Technical University
#
# Found in database  Malayer Azad University
#
# Found in database  Marietta College
#
# Found in database  Masdar Institute
#
# Found in database  Matematicki fakultet Beograd
#
# Found in database  Michigan State University
#
# Found in database  Middle East Technical University
#
# Found in database  Missouri University of Science and Technology
#
# Found in database  Monash
#
# Found in database  Monash University
#
# Found in database  Monash University Churchill Australia
#
# Found in database  Monterrey Institute of Technology and Higher Education
#
# Found in database  Moscow Engineering-Physics Institute
#
# Found in database  Moscow Institute of Physics & Technology
#
# Found in database  Moscow State University
#
# Found in database  NIT ROURKELA
#
# Found in database  NYU
#
# Found in database  Nagpur University
#
# Found in database  Nanyang Technological University
#
# Found in database  National Institute of Technology Jalandhar
#
# Found in database  National Taiwan University
#
# Found in database  National University of Engineering
#
# Found in database  North Central College
#
# Found in database  Northeastern University
#
# Found in database  Northwestern University
#
# Found in database  Obninsk Technical University of Nuclear Power Engineering Russia
#
# Found in database  Old Dominion University
#
# Found in database  Oregon Institute of Technology
#
# Found in database  PUCMM
#
# Found in database  Payame Noor University
#
# Found in database  Penn State University
#
# Found in database  Politecnico di Milano
#
# Found in database  Politehnica University Bucharest
#
# Found in database  Polytechnic University of Timisoara
#
# Found in database  Pondicherry University
#
# Found in database  Pontificia universidad catolica de chile
#
# Found in database  Portland State University
#
# Found in database  Purdue University Indianapolis
#
# Found in database  R V College of Engineering
#
# Found in database  RPI
#
# Found in database  Ramapo College of New Jersey
#
# Found in database  Rochester Institute of Technology
#
# Found in database  SASTRA University
#
# Found in database  Saint Petersburg State University
#
# Found in database  Saint Petersburg State University of Aerospace Instrumentation
#
# Found in database  Saint-Petersburg Polytechnic Univesity
#
# Found in database  San Francisco State University
#
# Found in database  San Jose State University
#
# Found in database  Shanghai Jiao Tong University
#
# Found in database  Sharif University of Technology
#
# Found in database  Simon Bolivar University
#
# Found in database  Simon Fraser University
#
# Found in database  Smolensk State University
#
# Found in database  Sonoma State University
#
# Found in database  South Federal University
#
# Found in database  Spiru Haret University
#
# Found in database  Stanford
#
# Found in database  State University of Campinas
#
# Found in database  State University of New York College at Oswego
#
# Found in database  Stellenbosch University
#
# Found in database  Stonehill College
#
# Found in database  Tallinn University
#
# Found in database  Tallinn University of Technology
#
# Found in database  Tampere University of Technology
#
# Found in database  Tanta University
#
# Found in database  Tarrant County College
#
# Found in database  Technical University of Cluj-Napoca
#
# Found in database  Technion
#
# Found in database  Tel Aviv University
#
# Found in database  The Jerusalem collage of engineering
#
# Found in database  The University of Latvia
#
# Found in database  The University of Manchester
#
# Found in database  The University of South Africa
#
# Found in database  Transilvania University
#
# Found in database  Tufts University
#
# Found in database  UC Berkeley
#
# Found in database  UCLA
#
# Found in database  UCSD
#
# Found in database  UIUC
#
# Found in database  UMD
#
# Found in database  UNISA
#
# Found in database  UNIVERSIDAD DE Buenos Aires
#
# Found in database  UOC
#
# Found in database  USC
#
# Found in database  UW Madison
#
# Found in database  Universidad Central de Venezuela
#
# Found in database  Universidad Complutense de Madrid
#
# Found in database  Universidad Cooperativa de Colombia
#
# Found in database  Universidad Nacional Autonoma de Mexico
#
# Found in database  Universidad Nacional Costa Rica
#
# Found in database  Universidad Nacional de Colombia
#
# Found in database  Universidad Tecnologica Boliviana
#
# Found in database  Universidad de Buenos Aires
#
# Found in database  Universidad de Castilla La Mancha
#
# Found in database  Universidad de Los Andes Colombia
#
# Found in database  Universidad de Oriente
#
# Found in database  Universidad de San Carlos de Guatemala
#
# Found in database  Universidad de Valladolid
#
# Found in database  Universidad de la Sabana
#
# Found in database  Universidad del Valle de Guatemala
#
# Found in database  Universidade Federal da Paraiba
#
# Found in database  Universidade Federal de Santa Catarina
#
# Found in database  Universidade Federal do Rio Grande do Sul
#
# Found in database  Universidade Federal do Rio de Janeiro
#
# Found in database  Universidade Tecnica de Lisboa
#
# Found in database  Universidade de Sao Paulo
#
# Found in database  Universidade do Minho
#
# Found in database  Universitas Gadjah Mada
#
# Resolving Universitat Politecnica de Valencia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universitat+Politecnica+de+Valencia
# Retrieved 1941 characters {    "results" : [
#
# Resolving Universite Catholique de Louvain
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Universite+Catholique+de+Louvain
# Retrieved 1917 characters {    "results" : [
#
# Resolving University College Dublin
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+College+Dublin
# Retrieved 11153 characters {    "results" : [
#
# Resolving University Munich
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+Munich
# Retrieved 15205 characters {    "results" : [
#
# Resolving University of Akron
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Akron
# Retrieved 1965 characters {    "results" : [
#
# Resolving University of Alberta
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Alberta
# Retrieved 2262 characters {    "results" : [
#
# Resolving University of Amsterdam
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Amsterdam
# Retrieved 1953 characters {    "results" : [
#
# Resolving University of Arkansas
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Arkansas
# Retrieved 2322 characters {    "results" : [
#
# Resolving University of Athens
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Athens
# Retrieved 2256 characters {    "results" : [
#
# Resolving University of Belgrade
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Belgrade
# Retrieved 2270 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Birmingham
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Birmingham
# Retrieved 12648 characters {    "results" : [
#
# Resolving University of Buenos Aires
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Buenos+Aires
# Retrieved 2108 characters {    "results" : [
#
# Resolving University of Cambridge
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Cambridge
# Retrieved 2113 characters {    "results" : [
#
# Resolving University of Central Oklahoma
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Central+Oklahoma
# Retrieved 2101 characters {    "results" : [
#
# Resolving University of Chicago
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Chicago
# Retrieved 2140 characters {    "results" : [
#
# Resolving University of Cincinnati
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Cincinnati
# Retrieved 2081 characters {    "results" : [
#
# Resolving University of Colorado at Boulder
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Colorado+at+Boulder
# Retrieved 1896 characters {    "results" : [
#
# Resolving University of Connecticut
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Connecticut
# Retrieved 1772 characters {    "results" : [
#
# Resolving University of Dallas
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Dallas
# Retrieved 27559 characters {    "results" : [
#
# Resolving University of Debrecen
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Debrecen
# Retrieved 1947 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Delaware
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Delaware
# Retrieved 14059 characters {    "results" : [
#
# Resolving University of Erlangen-Nuremberg
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Erlangen-Nuremberg
# Retrieved 2414 characters {    "results" : [
#
# Resolving University of Essex
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Essex
# Retrieved 13170 characters {    "results" : [
#
# Resolving University of Evora
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Evora
# Retrieved 1795 characters {    "results" : [
#
# Resolving University of Florida
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Florida
# Retrieved 10931 characters {    "results" : [
#
# Resolving University of Gothenburg
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Gothenburg
# Retrieved 2667 characters {    "results" : [
#
# Resolving University of Greifswald
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Greifswald
# Retrieved 1586 characters {    "results" : [
#
# Resolving University of Hamburg
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Hamburg
# Retrieved 13482 characters {    "results" : [
#
# Resolving University of Hawaii
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Hawaii
# Retrieved 2084 characters {    "results" : [
#
# Resolving University of Helsinki
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Helsinki
# Retrieved 1755 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Ilorin Kwara State
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Ilorin+Kwara+State
# Retrieved 5147 characters {    "results" : [
#
# Resolving University of Jaffna
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Jaffna
# Retrieved 1964 characters {    "results" : [
#
# Resolving University of Kansas
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Kansas
# Retrieved 2174 characters {    "results" : [
#
# Resolving University of Kerala
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Kerala
# Retrieved 14417 characters {    "results" : [
#
# Resolving University of London
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+London
# Retrieved 2307 characters {    "results" : [
#
# Resolving University of Malaga
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Malaga
# Retrieved 2251 characters {    "results" : [
#
# Resolving University of Malaya
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Malaya
# Retrieved 3874 characters {    "results" : [
#
# Resolving University of Manchester
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Manchester
# Retrieved 11051 characters {    "results" : [
#
# Resolving University of Michigan
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Michigan
# Retrieved 1914 characters {    "results" : [
#
# Resolving University of Missouri - Columbia
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Missouri+-+Columbia
# Retrieved 14965 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Moratuwa
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Moratuwa
# Retrieved 4137 characters {    "results" : [
#
# Resolving University of Mumbai
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Mumbai
# Retrieved 2826 characters {    "results" : [
#
# Resolving University of Nebraska
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Nebraska
# Retrieved 2086 characters {    "results" : [
#
# Resolving University of Nebraska - Lincoln
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Nebraska+-+Lincoln
# Retrieved 7065 characters {    "results" : [
#
# Resolving University of New Haven
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+New+Haven
# Retrieved 12737 characters {    "results" : [
#
# Resolving University of New South Wales
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+New+South+Wales
# Retrieved 1776 characters {    "results" : [
#
# Resolving University of Notre Dame
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Notre+Dame
# Retrieved 13274 characters {    "results" : [
#
# Resolving University of Oklahoma
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Oklahoma
# Retrieved 2094 characters {    "results" : [
#
# Resolving University of Ottawa
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Ottawa
# Retrieved 2127 characters {    "results" : [
#
# Resolving University of Oxford
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Oxford
# Retrieved 2126 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Padua
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Padua
# Retrieved 36375 characters {    "results" : [
#
# Resolving University of Pavia Italy
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Pavia+Italy
# Retrieved 1934 characters {    "results" : [
#
# Resolving University of Pennsylvania
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Pennsylvania
# Retrieved 10169 characters {    "results" : [
#
# Resolving University of Piraeus Athens
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Piraeus+Athens
# Retrieved 11265 characters {    "results" : [
#
# Resolving University of Pretoria
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Pretoria
# Retrieved 2426 characters {    "results" : [
#
# Resolving University of Salamanca
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Salamanca
# Retrieved 2071 characters {    "results" : [
#
# Resolving University of Sao Paulo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Sao+Paulo
# Retrieved 18511 characters {    "results" : [
#
# Resolving University of Sarajevo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Sarajevo
# Retrieved 1847 characters {    "results" : [
#
# Resolving University of Southern California
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Southern+California
# Retrieved 1970 characters {    "results" : [
#
# Resolving University of Stellenbosch
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Stellenbosch
# Retrieved 2567 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Tartu
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Tartu
# Retrieved 1880 characters {    "results" : [
#
# Resolving University of Tehran
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Tehran
# Retrieved 6206 characters {    "results" : [
#
# Resolving University of Texas
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Texas
# Retrieved 2274 characters {    "results" : [
#
# Resolving University of Texas at Austin
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Texas+at+Austin
# Retrieved 1994 characters {    "results" : [
#
# Resolving University of Toronto
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Toronto
# Retrieved 2186 characters {    "results" : [
#
# Resolving University of Tuebingen
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Tuebingen
# Retrieved 1949 characters {    "results" : [
#
# Resolving University of Twente
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Twente
# Retrieved 2124 characters {    "results" : [
#
# Resolving University of Utah
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Utah
# Retrieved 10547 characters {    "results" : [
#
# Resolving University of Vienna
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Vienna
# Retrieved 2107 characters {    "results" : [
#
# Resolving University of Warsaw
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Warsaw
# Retrieved 1928 characters {    "results" : [
# Pausing for a bit...
#
# Resolving University of Washington
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Washington
# Retrieved 2275 characters {    "results" : [
#
# Resolving University of Washington - Bothell
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Washington+-+Bothell
# Retrieved 2004 characters {    "results" : [
#
# Resolving University of Waterloo
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Waterloo
# Retrieved 2001 characters {    "results" : [
#
# Resolving University of West Florida
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+West+Florida
# Retrieved 2187 characters {    "results" : [
#
# Resolving University of Wisconsin
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+Wisconsin
# Retrieved 1772 characters {    "results" : [
#
# Resolving University of the Punjab Lahore
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+the+Punjab+Lahore
# Retrieved 2192 characters {    "results" : [
#
# Resolving University of the Witwatersrand
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=University+of+the+Witwatersrand
# Retrieved 2959 characters {    "results" : [
#
# Resolving Vilnius Gediminas Technical University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Vilnius+Gediminas+Technical+University
# Retrieved 1790 characters {    "results" : [
#
# Resolving Vilnius University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Vilnius+University
# Retrieved 1790 characters {    "results" : [
#
# Resolving Virginia Commonwealth University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Virginia+Commonwealth+University
# Retrieved 4713 characters {    "results" : [
# Pausing for a bit...
#
# Resolving Virginia Tech
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Virginia+Tech
# Retrieved 2130 characters {    "results" : [
#
# Resolving Viswakarma Institute Pune India
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Viswakarma+Institute+Pune+India
# Retrieved 2578 characters {    "results" : [
#
# Resolving Warsaw University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Warsaw+University
# Retrieved 1928 characters {    "results" : [
#
# Resolving Washington State University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Washington+State+University
# Retrieved 2337 characters {    "results" : [
#
# Resolving Wayne State
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Wayne+State
# Retrieved 2280 characters {    "results" : [
#
# Resolving Weber State
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Weber+State
# Retrieved 2277 characters {    "results" : [
#
# Resolving Weizmann Institute of Science
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Weizmann+Institute+of+Science
# Retrieved 2194 characters {    "results" : [
#
# Resolving Western Governors University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Western+Governors+University
# Retrieved 2184 characters {    "results" : [
#
# Resolving Xavier University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Xavier+University
# Retrieved 9748 characters {    "results" : [
#
# Resolving Zagazig University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=Zagazig+University
# Retrieved 6901 characters {    "results" : [
# Pausing for a bit...
#
# Resolving allama iqbal open university islamabad
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=allama+iqbal+open+university+islamabad
# Retrieved 2157 characters {    "results" : [
#
# Resolving arizona state university
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=arizona+state+university
# Retrieved 2098 characters {    "results" : [
#
# Resolving federal institute of tecnology and education from southeastern Minas Gerais
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=federal+institute+of+tecnology+and+education+from+southeastern+Minas+Gerais
# Retrieved 1444 characters {    "results" : [
#
# Resolving kansas state university
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=kansas+state+university
# Retrieved 1972 characters {    "results" : [
#
# Resolving universidad complutense de madrid
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=universidad+complutense+de+madrid
# Retrieved 1929 characters {    "results" : [
#
# Resolving university of Patras
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=university+of+Patras
# Retrieved 4169 characters {    "results" : [
#
# Resolving university of padua
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=university+of+padua
# Retrieved 36375 characters {    "results" : [
# Run geodump.py to read the data from the database so you can visualize it on a map.

# %% [markdown]
# Data Retrieved completly, now starting visualization!
# Loading geodump.py
#
# *Retrieved 200 locations, restart to retrieve more
# Run geodump.py to read the data from the database so you can visualize it on a map.*

# %%
import sqlite3
import json
import codecs

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js','w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1])
    try: js = json.loads(str(data))
    except: continue

    if not('status' in js and js['status'] == 'OK') : continue

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    if lat == 0 or lng == 0 : continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'","")
    try :
        print where, lat, lng

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
print count, "records written to where.js"
print "Open where.html to view the data in a browser"
# Out:
# Dormitory no. 14 "Kapitol" of AGH University of Science and Technology in Cracov, Poland, Witolda Budryka 2, 30-072 Kraków, Poland 50.0676785 19.9070824
# Warsaw, Poland 52.2296756 21.0122287
# American University Housing District, Cairo Governorate, Egypt 30.0068972 31.5005988
# State Ave, Tempe, AZ 85281, USA 33.4232051 -111.8879509
# Information Technology Services, 2500 Daniels Bridge Rd, Athens, GA 30606, USA 33.9094658 -83.4604372
# BITS, Pilani, Rajasthan 333031, India 28.3580163 75.5887989
# South Hall Tufts University, 30 Lower Campus Rd, Somerville, MA 02144, USA 42.4036847 -71.120482
# California St, Berkeley, CA, USA 37.8764984 -122.2804342
# Ucla Ln, Altoona, PA 16602, USA 40.5382913 -78.3528584
# UC San Diego School of Management, La Jolla, CA 92093, USA 32.8866612 -117.2413398
# UIUC Engineering Hall, Urbana, IL 61801, USA 40.110833 -88.226944
# Japan, 〒875-0002 Ōita-ken, Usuki-shi, Shitanoe, 1232−2 ＵＭＤ 33.1561058 131.826132
# Yungondi Building, North Terrace, Adelaide SA 5000, Australia -34.9221963 138.5922272
# Universidad de Buenos Aires, Manuel Alberti, Buenos Aires, Argentina -34.4414891 -58.7595663
# New York, NY, USA 40.7127837 -74.0059413
# Usc, 6749, Switzerland 46.4062583 8.9040484
# University of Wisconsin-Madison Arboretum, 1207 Seminole Hwy, Madison, WI 53711, USA 43.0447617 -89.4245627
# Ave Central, San Juan, San Juan, Puerto Rico 18.4074917 -66.062465
# Av. Complutense, Madrid, Madrid, Spain 40.4469796 -3.7278167
# Universidad Cooperativa de Colombia Bloque 31, Bogotá, Colombia 4.7500846 -74.032709
# National Autonomous University of Mexico, Mexico City, Federal District, Mexico 19.3188895 -99.1843676
# Universidad Nacional, 150, Nicoya, Costa Rica 10.1345309 -85.4467445
# Colombia, Loja, Ecuador -4.009976 -79.2085378
# Bolivia, Plaza de las Americas, 76048 Santiago de Querétaro, Qro., Mexico 20.5898607 -100.3751526
# Universidad de Buenos Aires, Manuel Alberti, Buenos Aires, Argentina -34.4414891 -58.7595663
# Universidad, 28801 Alcalá de Henares, Madrid, Spain 40.480453 -3.3638513
# Parqueadero Universidad Del Valle, Cali, Cali, Valle del Cauca, Colombia 3.4321247 -76.5461709
# Universidad de Oriente, Avenida 21 Oriente 1816, Zona Sin Asignación de Nombre de Col 39, Azcarate, Puebla, Pue., Mexico 19.0303192 -98.1903344
# Bufete Popular Universidad de San Carlos, Guatemala City, Guatemala 14.6360021 -90.5095397
# Universidad, 47002 Valladolid, Valladolid, Spain 41.6518587 -4.7215284
# Universidad De La Sabana, Chía, Chía, Cundinamarca, Colombia 4.8602595 -74.0333032
# Guatemala, Cd Madero, Tamps., Mexico 22.2567635 -97.8345654
# Universidade Federal da Paraíba - CAVN - R. Santos Dumont, Bananeiras - PB, 58220-000, Brazil -6.7515086 -35.6437193
# Calz Sta Catarina, Ciudad de México, D.F., Mexico 19.3490169 -99.1991009
# Ac. Universidade Federal do Rio Grande do Sul, Porto Alegre - RS, Brazil -30.0699518 -51.118329
# Cidade Universitária, Rio de Janeiro - State of Rio de Janeiro, Brazil -22.8626877 -43.2258954
# Av. Universidade Técnica, Lisboa, Portugal 38.7139308 -9.1971988
# Av. da Universidade - Butantã, São Paulo - SP, Brazil -23.5634327 -46.7159511
# Universidade do Minho, 4710 Braga, Portugal 41.557583 -8.397568
# Pusat Studi Keamanan dan Perdamaian Universitas Gadjah Mada (PSKP UGM), Sinduadi, Mlati, Sleman Regency 55281, Indonesia -7.771949 110.374874
# 201 records written to where.js
# Open where.html to view the data in a browser
